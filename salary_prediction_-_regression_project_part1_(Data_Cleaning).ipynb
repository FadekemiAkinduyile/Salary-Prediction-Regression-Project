# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
jobs = pd.read_csv('job_postings.csv')
jobs.head()
# Out:
#       job_id  company_id                     title  \
# 0   85008768         NaN  Licensed Insurance Agent
# 1  133114754  77766802.0             Sales Manager
# 2  133196985   1089558.0        Model Risk Auditor
# 3  381055942  96654609.0          Business Manager
# 4  529257371   1244539.0       NY Studio Assistant
#
#                                          description  max_salary  med_salary  \
# 0  While many industries were hurt by the last fe...     52000.0         NaN
# 1  Are you a dynamic and creative marketing profe...         NaN         NaN
# 2  Join Us as a Model Risk Auditor – Showcase You...         NaN         NaN
# 3  Business ManagerFirst Baptist Church ForneyFor...         NaN         NaN
# 4  YOU COULD BE ONE OF THE MAGIC MAKERS\nKen Fulk...         NaN         NaN
#
#    min_salary pay_period formatted_work_type           location  ...  \
# 0     45760.0     YEARLY           Full-time          Chico, CA  ...
# ...

# %%
jobs.tail()
# Out:
#            job_id  company_id                                  title  \
# 15881  3701373516  74718032.0                  Sanitation Technician
# 15882  3701373522     38897.0                         Unit Secretary
# 15883  3701373523     38897.0                Radiology Aide, Perdiem
# 15884  3701373524      2623.0                            MRI Manager
# 15885  3701373527     84659.0  Area Director of Business Development
#
#                                              description  max_salary  \
# 15881  Location:\n\nWest Columbia, SC, US, 29172\n\n2...         NaN
# 15882  Job Title: Unit Secretary\nDepartment: Nursing...         NaN
# 15883  Job Title: Radiology Aide, Perdiem\nDepartment...         NaN
# 15884  Grade 105\nJob Type: Officer of Administration...    135000.0
# 15885  Nexion Health Management affiliates operate 56...         NaN
#
#        med_salary  min_salary pay_period formatted_work_type  \
# 15881         NaN         NaN        NaN           Part-time
# ...

# %%
jobs.shape
# Out:
# (15886, 27)

# %%
#check for uniques values in currency column and saw only USD. Will drop as its redundant.

jobs['currency'].unique()
# Out:
# array(['USD', nan], dtype=object)

# %%
#check for uniques values in compensation_type column and saw only 'BASE_SALARY'. Will drop as its redundant.

jobs['compensation_type'].unique()
# Out:
# array(['BASE_SALARY', nan], dtype=object)

# %%
jobs['formatted_experience_level'].unique()
# Out:
# array([nan, 'Entry level', 'Associate', 'Mid-Senior level', 'Director',
#        'Executive', 'Internship'], dtype=object)

# %%
jobs['application_type'].unique()
# Out:
# array(['ComplexOnsiteApply', 'OffsiteApply', 'SimpleOnsiteApply'],
#       dtype=object)

# %%
#formatted_work_type and work_type columns as the same. Will drop work_type column
#https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.equals.html
# This code wouldnt work because the entries format are different
#identical = jobs['formatted_work_type'].equals(jobs['work_type'])
#print(identical)

# %%
print(jobs['location'].mode())

count = jobs['location'].value_counts()
value = count.head(3)
print(value)

#https://pandas.pydata.org/docs/reference/api/pandas.Series.str.split.html
# extract state name from state name, abbreviation, e.g New York from New York, NY
# Location column will be dropped subsequently
jobs['city'] = jobs['location'].str.split(",").str[0].str.split(" City").str[0].str.split(" Bay").str[0].str.split(" DC-Baltimore").str[0].str.split(" Metropolitan").str[0].str.strip()
count = jobs['city'].value_counts()
value = count.head(10)
print(value)
# Out:
# 0    United States
# Name: location, dtype: object
# United States    1133
# New York, NY      398
# Chicago, IL       267
# Name: location, dtype: int64
# United States    1133
# New York          607
# Chicago           267
# Los Angeles       245
# Houston           243
# Atlanta           237
# San Francisco     209
# Austin            205
# Dallas            183
# Washington        174
# Name: city, dtype: int64

# %%
value = count.tail()
print(value)

#check single entries by city column
value_counts = jobs['city'].value_counts()
count_of_ones = value_counts[value_counts == 1]
print(count_of_ones.sum())
# Out:
# Weymouth        1
# Ocean View      1
# Breckenridge    1
# Hackettstown    1
# Vicksburg       1
# Name: city, dtype: int64
# 1191

# %%
# Remove irrelevant columns
jobs.drop(columns=['description', 'location', 'applies', 'original_listed_time', 'remote_allowed', 'views', 'job_posting_url', 'application_url', 'expiry', 'closed_time', 'skills_desc', 'listed_time', 'posting_domain', 'sponsored', 'work_type', 'currency', 'compensation_type'], axis=0, inplace=True)
print(jobs.shape)
jobs.head()
# Out:
# (15886, 11)
#       job_id  company_id                     title  max_salary  med_salary  \
# 0   85008768         NaN  Licensed Insurance Agent     52000.0         NaN
# 1  133114754  77766802.0             Sales Manager         NaN         NaN
# 2  133196985   1089558.0        Model Risk Auditor         NaN         NaN
# 3  381055942  96654609.0          Business Manager         NaN         NaN
# 4  529257371   1244539.0       NY Studio Assistant         NaN         NaN
#
#    min_salary pay_period formatted_work_type    application_type  \
# 0     45760.0     YEARLY           Full-time  ComplexOnsiteApply
# 1         NaN        NaN           Full-time  ComplexOnsiteApply
# 2         NaN        NaN            Contract  ComplexOnsiteApply
# 3         NaN        NaN           Full-time  ComplexOnsiteApply
# 4         NaN        NaN           Full-time  ComplexOnsiteApply
#
#   formatted_experience_level           city
# 0                        NaN          Chico
# ...

# %%
#Check dataframe details

jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15886 entries, 0 to 15885
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   job_id                      15886 non-null  int64
#  1   company_id                  15520 non-null  float64
#  2   title                       15886 non-null  object
#  3   max_salary                  5521 non-null   float64
#  4   med_salary                  981 non-null    float64
#  5   min_salary                  5521 non-null   float64
#  6   pay_period                  6502 non-null   object
#  7   formatted_work_type         15886 non-null  object
#  8   application_type            15886 non-null  object
#  9   formatted_experience_level  10984 non-null  object
#  10  city                        15886 non-null  object
# dtypes: float64(4), int64(1), object(6)
# memory usage: 1.3+ MB

# %%
# Adding relevant columns from other csv files

# %% [markdown]
# # **Merge, Join, Concatenate**
# https://pandas.pydata.org/docs/user_guide/merging.html

# %% [markdown]
# **Skills**

# %%
skills = pd.read_csv('job_skills.csv')
skills.head()
# Out:
#        job_id skill_abr
# 0  3690843087      ACCT
# 1  3690843087       FIN
# 2  3691763971      MGMT
# 3  3691763971      MNFC
# 4  3691775263      MGMT

# %%
skills.drop_duplicates(subset='job_id', keep='first', inplace=True)
skills.head()
# Out:
#        job_id skill_abr
# 0  3690843087      ACCT
# 2  3691763971      MGMT
# 4  3691775263      MGMT
# 6  3691786992      HCPR
# 7  3691789797      MGMT

# %%
jobs = pd.merge(jobs, skills, on='job_id', how='left')
jobs.head()
# Out:
#       job_id  company_id                     title  max_salary  med_salary  \
# 0   85008768         NaN  Licensed Insurance Agent     52000.0         NaN
# 1  133114754  77766802.0             Sales Manager         NaN         NaN
# 2  133196985   1089558.0        Model Risk Auditor         NaN         NaN
# 3  381055942  96654609.0          Business Manager         NaN         NaN
# 4  529257371   1244539.0       NY Studio Assistant         NaN         NaN
#
#    min_salary pay_period formatted_work_type    application_type  \
# 0     45760.0     YEARLY           Full-time  ComplexOnsiteApply
# 1         NaN        NaN           Full-time  ComplexOnsiteApply
# 2         NaN        NaN            Contract  ComplexOnsiteApply
# 3         NaN        NaN           Full-time  ComplexOnsiteApply
# 4         NaN        NaN           Full-time  ComplexOnsiteApply
#
#   formatted_experience_level           city skill_abr
# 0                        NaN          Chico      SALE
# ...

# %% [markdown]
# **Benefits**

# %%
benefits = pd.read_csv('benefits.csv')
benefits.head()
# Out:
#        job_id  inferred                  type
# 0  3690843087         0     Medical insurance
# 1  3690843087         0      Dental insurance
# 2  3690843087         0                401(k)
# 3  3690843087         0  Paid maternity leave
# 4  3690843087         0  Disability insurance

# %%
# Create a new DataFrame to store unique 'job_id' and their corresponding 'benefits'
unique_job_ids = jobs['job_id'].unique()
benefits_type = []

# Iterate through unique 'job_id' and determine 'benefits' based on set conditions
for job_id in unique_job_ids:
    insurance = benefits[benefits['job_id'] == job_id]
    if any(insurance['type'].isin(['Medical insurance', 'Dental insurance', 'Vision insurance'])):
        benefits_type.append({'job_id': job_id, 'benefits': 'Basic'})
    elif any(insurance['type'].isin(['Paid maternity leave', 'Commuter benefits', 'Disability insurance'])):
        benefits_type.append({'job_id': job_id, 'benefits': 'Standard'})
    else:
        benefits_type.append({'job_id': job_id, 'benefits': 'Premium'})

# Create the 'benefits' DataFrame
benefits_df = pd.DataFrame(benefits_type)

# Merge the 'jobs' DataFrame and the 'benefits' DataFrame on 'job_id'
jobs = pd.merge(jobs, benefits_df, on='job_id', how='left')

# %%
jobs.head()
# Out:
#       job_id  company_id                     title  max_salary  med_salary  \
# 0   85008768         NaN  Licensed Insurance Agent     52000.0         NaN
# 1  133114754  77766802.0             Sales Manager         NaN         NaN
# 2  133196985   1089558.0        Model Risk Auditor         NaN         NaN
# 3  381055942  96654609.0          Business Manager         NaN         NaN
# 4  529257371   1244539.0       NY Studio Assistant         NaN         NaN
#
#    min_salary pay_period formatted_work_type    application_type  \
# 0     45760.0     YEARLY           Full-time  ComplexOnsiteApply
# 1         NaN        NaN           Full-time  ComplexOnsiteApply
# 2         NaN        NaN            Contract  ComplexOnsiteApply
# 3         NaN        NaN           Full-time  ComplexOnsiteApply
# 4         NaN        NaN           Full-time  ComplexOnsiteApply
#
#   formatted_experience_level           city skill_abr benefits
# ...

# %%
jobs['benefits'].unique()
# Out:
# array(['Basic', 'Premium', 'Standard'], dtype=object)

# %% [markdown]
# **Industry**

# %%
Ind = pd.read_csv('company_industries.csv')
Ind.head()
# Out:
#    company_id                               industry
# 0    81149246                       Higher Education
# 1    10033339      Information Technology & Services
# 2     6049228                             Accounting
# 3     2641066  Electrical & Electronic Manufacturing
# 4    96649998                Marketing & Advertising

# %%
print(Ind.shape)
Ind.drop_duplicates(subset='company_id', keep='first', inplace=True)
Ind.head()
Ind.shape
# Out:
# (15880, 2)
# (6003, 2)

# %%
jobs = pd.merge(jobs, Ind, on='company_id', how='left')
jobs.head()
# Out:
#       job_id  company_id                     title  max_salary  med_salary  \
# 0   85008768         NaN  Licensed Insurance Agent     52000.0         NaN
# 1  133114754  77766802.0             Sales Manager         NaN         NaN
# 2  133196985   1089558.0        Model Risk Auditor         NaN         NaN
# 3  381055942  96654609.0          Business Manager         NaN         NaN
# 4  529257371   1244539.0       NY Studio Assistant         NaN         NaN
#
#    min_salary pay_period formatted_work_type    application_type  \
# 0     45760.0     YEARLY           Full-time  ComplexOnsiteApply
# 1         NaN        NaN           Full-time  ComplexOnsiteApply
# 2         NaN        NaN            Contract  ComplexOnsiteApply
# 3         NaN        NaN           Full-time  ComplexOnsiteApply
# 4         NaN        NaN           Full-time  ComplexOnsiteApply
#
#   formatted_experience_level           city skill_abr benefits  \
# ...

# %%
#Used values in 'med_salary' to fill missing values in 'min_salary' and 'max_salary' which increase values fron 5521 to 6502

jobs['min_salary'].fillna(jobs['med_salary'], inplace=True)
jobs['max_salary'].fillna(jobs['med_salary'], inplace=True)
jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15886 entries, 0 to 15885
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   job_id                      15886 non-null  int64
#  1   company_id                  15520 non-null  float64
#  2   title                       15886 non-null  object
#  3   max_salary                  6502 non-null   float64
#  4   med_salary                  981 non-null    float64
#  5   min_salary                  6502 non-null   float64
#  6   pay_period                  6502 non-null   object
#  7   formatted_work_type         15886 non-null  object
#  8   application_type            15886 non-null  object
#  9   formatted_experience_level  10984 non-null  object
#  10  city                        15886 non-null  object
#  11  skill_abr                   15249 non-null  object
#  12  benefits                    15886 non-null  object
# ...

# %%
#dropped 'med_salary' column, as well as,  job_id	company_id. They are no longer required/relevant

jobs.drop(columns=['med_salary', 'job_id', 'company_id'], axis=0, inplace=True)
jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15886 entries, 0 to 15885
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   title                       15886 non-null  object
#  1   max_salary                  6502 non-null   float64
#  2   min_salary                  6502 non-null   float64
#  3   pay_period                  6502 non-null   object
#  4   formatted_work_type         15886 non-null  object
#  5   application_type            15886 non-null  object
#  6   formatted_experience_level  10984 non-null  object
#  7   city                        15886 non-null  object
#  8   skill_abr                   15249 non-null  object
#  9   benefits                    15886 non-null  object
#  10  industry                    15493 non-null  object
# dtypes: float64(2), object(9)
# memory usage: 1.5+ MB

# %%
# create a new column 'salary' from the average of 'min_salary' and 'max_salary' values
jobs['salary'] = (jobs['min_salary'] + jobs['max_salary']) / 2
jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15886 entries, 0 to 15885
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   title                       15886 non-null  object
#  1   max_salary                  6502 non-null   float64
#  2   min_salary                  6502 non-null   float64
#  3   pay_period                  6502 non-null   object
#  4   formatted_work_type         15886 non-null  object
#  5   application_type            15886 non-null  object
#  6   formatted_experience_level  10984 non-null  object
#  7   city                        15886 non-null  object
#  8   skill_abr                   15249 non-null  object
#  9   benefits                    15886 non-null  object
#  10  industry                    15493 non-null  object
#  11  salary                      6502 non-null   float64
# dtypes: float64(3), object(9)
# memory usage: 1.6+ MB

# %%
#https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.groupby.html
#https://pandas.pydata.org/docs/dev/reference/api/pandas.DataFrame.map.html
#https://stackoverflow.com/questions/67988357/how-to-use-pandas-map-function-without-overwriting-items-that-do-not-match

# used the mean of salary grouped by title to fill in missing values in the 'salary' column. This increased from 6502 to 8304

mean_salary_by_title = jobs.groupby(['title'])['salary'].mean()
jobs['salary'].fillna(jobs['title'].map(mean_salary_by_title), inplace=True)
jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15886 entries, 0 to 15885
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   title                       15886 non-null  object
#  1   max_salary                  6502 non-null   float64
#  2   min_salary                  6502 non-null   float64
#  3   pay_period                  6502 non-null   object
#  4   formatted_work_type         15886 non-null  object
#  5   application_type            15886 non-null  object
#  6   formatted_experience_level  10984 non-null  object
#  7   city                        15886 non-null  object
#  8   skill_abr                   15249 non-null  object
#  9   benefits                    15886 non-null  object
#  10  industry                    15493 non-null  object
#  11  salary                      8304 non-null   float64
# dtypes: float64(3), object(9)
# memory usage: 1.6+ MB

# %%
#dropped 'min_salary' and 'max_salary' column as it is no longer required

jobs.drop(columns=['max_salary', 'min_salary'], axis=0, inplace=True)
jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15886 entries, 0 to 15885
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   title                       15886 non-null  object
#  1   pay_period                  6502 non-null   object
#  2   formatted_work_type         15886 non-null  object
#  3   application_type            15886 non-null  object
#  4   formatted_experience_level  10984 non-null  object
#  5   city                        15886 non-null  object
#  6   skill_abr                   15249 non-null  object
#  7   benefits                    15886 non-null  object
#  8   industry                    15493 non-null  object
#  9   salary                      8304 non-null   float64
# dtypes: float64(1), object(9)
# memory usage: 1.3+ MB

# %%
#dropped rows that have missing values in salary column

jobs.dropna(subset=['salary'], inplace=True)
print(jobs.shape)
jobs.info()
# Out:
# (8304, 10)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8304 entries, 0 to 15884
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   title                       8304 non-null   object
#  1   pay_period                  6502 non-null   object
#  2   formatted_work_type         8304 non-null   object
#  3   application_type            8304 non-null   object
#  4   formatted_experience_level  5616 non-null   object
#  5   city                        8304 non-null   object
#  6   skill_abr                   8096 non-null   object
#  7   benefits                    8304 non-null   object
#  8   industry                    8080 non-null   object
#  9   salary                      8304 non-null   float64
# dtypes: float64(1), object(9)
# memory usage: 713.6+ KB

# %%
jobs.head()
# Out:
#                       title pay_period formatted_work_type  \
# 0  Licensed Insurance Agent     YEARLY           Full-time
# 1             Sales Manager        NaN           Full-time
# 3          Business Manager        NaN           Full-time
# 5          Office Associate     YEARLY           Full-time
# 6         Education Manager        NaN           Full-time
#
#      application_type formatted_experience_level           city skill_abr  \
# 0  ComplexOnsiteApply                        NaN          Chico      SALE
# 1  ComplexOnsiteApply                        NaN  Santa Clarita      SALE
# 3  ComplexOnsiteApply                        NaN         Forney       NaN
# 5  ComplexOnsiteApply                        NaN         Albany       ADM
# 6        OffsiteApply                        NaN  United States       EDU
#
#   benefits                          industry         salary
# 0    Basic                               NaN   48880.000000
# ...

# %%
jobs.reset_index(drop=True, inplace=True)
jobs.head()
# Out:
#                       title pay_period formatted_work_type  \
# 0  Licensed Insurance Agent     YEARLY           Full-time
# 1             Sales Manager        NaN           Full-time
# 2          Business Manager        NaN           Full-time
# 3          Office Associate     YEARLY           Full-time
# 4         Education Manager        NaN           Full-time
#
#      application_type formatted_experience_level           city skill_abr  \
# 0  ComplexOnsiteApply                        NaN          Chico      SALE
# 1  ComplexOnsiteApply                        NaN  Santa Clarita      SALE
# 2  ComplexOnsiteApply                        NaN         Forney       NaN
# 3  ComplexOnsiteApply                        NaN         Albany       ADM
# 4        OffsiteApply                        NaN  United States       EDU
#
#   benefits                          industry         salary
# 0    Basic                               NaN   48880.000000
# ...

# %%
jobs['pay_period'].unique()
# Out:
# array(['YEARLY', nan, 'HOURLY', 'MONTHLY'], dtype=object)

# %%
# write a for loop to standardize salary values to yearly rates
#https://towardsdatascience.com/efficiently-iterating-over-rows-in-a-pandas-dataframe-7dd5f9992c01
#https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.iterrows.html
#https://stackoverflow.com/questions/16476924/how-to-iterate-over-rows-in-a-dataframe-in-pandas

# Initialize a list to store standardized salaries
yearly_salaries = []

# Iterate through the rows and standardize salaries
for index, row in jobs.iterrows():
    salary = row['salary']
    pay_period = row['pay_period']

    if not pd.isna(salary):
        if not pd.isna(pay_period):
            if pay_period == 'YEARLY':
                yearly_salaries.append(salary)
            elif pay_period == 'MONTHLY':
                yearly_salaries.append(salary * 12)
            elif pay_period == 'HOURLY':
                yearly_salaries.append(salary * 2080)  # Assuming 40 hours/week, 52 weeks/year
        else:
            if salary >= 20000:
                yearly_salaries.append(salary)  # Leave salary as is
            elif 1000 <= salary < 20000:
                yearly_salaries.append(salary * 12)
            else:
                yearly_salaries.append(salary * 2080)
    else:
        yearly_salaries.append(None)  # Handle cases where salary is NaN

# Add the standardized salaries to the DataFrame
jobs['yearly_salary'] = yearly_salaries

# %%
jobs.head()
# Out:
#                       title pay_period formatted_work_type  \
# 0  Licensed Insurance Agent     YEARLY           Full-time
# 1             Sales Manager        NaN           Full-time
# 2          Business Manager        NaN           Full-time
# 3          Office Associate     YEARLY           Full-time
# 4         Education Manager        NaN           Full-time
#
#      application_type formatted_experience_level           city skill_abr  \
# 0  ComplexOnsiteApply                        NaN          Chico      SALE
# 1  ComplexOnsiteApply                        NaN  Santa Clarita      SALE
# 2  ComplexOnsiteApply                        NaN         Forney       NaN
# 3  ComplexOnsiteApply                        NaN         Albany       ADM
# 4        OffsiteApply                        NaN  United States       EDU
#
#   benefits                          industry         salary  yearly_salary
# 0    Basic                               NaN   48880.000000   48880.000000
# ...

# %%
# since salary is now on yearly basis, the pay_period columns are no longer required
jobs.drop(columns=['pay_period', 'salary'], axis=0, inplace=True)
jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8304 entries, 0 to 8303
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   title                       8304 non-null   object
#  1   formatted_work_type         8304 non-null   object
#  2   application_type            8304 non-null   object
#  3   formatted_experience_level  5616 non-null   object
#  4   city                        8304 non-null   object
#  5   skill_abr                   8096 non-null   object
#  6   benefits                    8304 non-null   object
#  7   industry                    8080 non-null   object
#  8   yearly_salary               8304 non-null   float64
# dtypes: float64(1), object(8)
# memory usage: 584.0+ KB

# %%
jobs.head()
# Out:
#                       title formatted_work_type    application_type  \
# 0  Licensed Insurance Agent           Full-time  ComplexOnsiteApply
# 1             Sales Manager           Full-time  ComplexOnsiteApply
# 2          Business Manager           Full-time  ComplexOnsiteApply
# 3          Office Associate           Full-time  ComplexOnsiteApply
# 4         Education Manager           Full-time        OffsiteApply
#
#   formatted_experience_level           city skill_abr benefits  \
# 0                        NaN          Chico      SALE    Basic
# 1                        NaN  Santa Clarita      SALE    Basic
# 2                        NaN         Forney       NaN  Premium
# 3                        NaN         Albany       ADM  Premium
# 4                        NaN  United States       EDU  Premium
#
#                            industry  yearly_salary
# 0                               NaN   48880.000000
# 1  Transportation/Trucking/Railroad  124065.217391
# ...

# %%
jobs.isna().sum()
# Out:
# title                            0
# formatted_work_type              0
# application_type                 0
# formatted_experience_level    2688
# city                             0
# skill_abr                      208
# benefits                         0
# industry                       224
# yearly_salary                    0
# dtype: int64

# %%
jobs['formatted_experience_level'].unique()
# Out:
# array([nan, 'Entry level', 'Associate', 'Mid-Senior level', 'Director',
#        'Executive', 'Internship'], dtype=object)

# %%
mean_salary_by_experience_level = jobs.groupby(['formatted_experience_level'])['yearly_salary'].mean()
print(mean_salary_by_experience_level)
# Out:
# formatted_experience_level
# Associate            81923.571295
# Director            174928.828862
# Entry level          63015.118561
# Executive           183826.068947
# Internship           70966.300000
# Mid-Senior level    109541.151203
# Name: yearly_salary, dtype: float64

# %%
# Create an empty list to store the experience levels
experience_levels = []

# Categorize experience levels based on salary ranges using if statements
for salary, experience_level in zip(jobs['yearly_salary'], jobs['formatted_experience_level']):
  if pd.isna(experience_level):
    if 63000 <= salary < 70967:
      experience_levels.append('Entry level')
    elif 70967 <= salary < 81924:
      experience_levels.append('Internship')
    elif 81924 <= salary < 109542:
      experience_levels.append('Associate')
    elif 109542 <= salary < 174929:
      experience_levels.append('Mid-Senior level')
    elif 174929 <= salary < 183827:
      experience_levels.append('Director')
    else:
      experience_levels.append('Executive')
  else:
    experience_levels.append(experience_level)

# Add the experience levels to the DataFrame
jobs['formatted_experience_level'] = experience_levels

jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8304 entries, 0 to 8303
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   title                       8304 non-null   object
#  1   formatted_work_type         8304 non-null   object
#  2   application_type            8304 non-null   object
#  3   formatted_experience_level  8304 non-null   object
#  4   city                        8304 non-null   object
#  5   skill_abr                   8096 non-null   object
#  6   benefits                    8304 non-null   object
#  7   industry                    8080 non-null   object
#  8   yearly_salary               8304 non-null   float64
# dtypes: float64(1), object(8)
# memory usage: 584.0+ KB

# %%
skill_by_title = jobs.groupby(['title'])['skill_abr'].first()
jobs['skill_abr'].fillna(jobs['title'].map(skill_by_title), inplace=True)
jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8304 entries, 0 to 8303
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   title                       8304 non-null   object
#  1   formatted_work_type         8304 non-null   object
#  2   application_type            8304 non-null   object
#  3   formatted_experience_level  8304 non-null   object
#  4   city                        8304 non-null   object
#  5   skill_abr                   8165 non-null   object
#  6   benefits                    8304 non-null   object
#  7   industry                    8080 non-null   object
#  8   yearly_salary               8304 non-null   float64
# dtypes: float64(1), object(8)
# memory usage: 584.0+ KB

# %%
ind_by_title = jobs.groupby(['title'])['industry'].first()
jobs['industry'].fillna(jobs['title'].map(ind_by_title), inplace=True)

# %%
jobs.isna().sum()
# Out:
# title                           0
# formatted_work_type             0
# application_type                0
# formatted_experience_level      0
# city                            0
# skill_abr                     139
# benefits                        0
# industry                       82
# yearly_salary                   0
# dtype: int64

# %%
jobs.dropna(subset=['skill_abr'], inplace=True)
jobs.reset_index(drop=True, inplace=True)
jobs.isna().sum()
# Out:
# title                          0
# formatted_work_type            0
# application_type               0
# formatted_experience_level     0
# city                           0
# skill_abr                      0
# benefits                       0
# industry                      48
# yearly_salary                  0
# dtype: int64

# %%
jobs.dropna(subset=['industry'], inplace=True)
jobs.reset_index(drop=True, inplace=True)
jobs.isna().sum()
# Out:
# title                         0
# formatted_work_type           0
# application_type              0
# formatted_experience_level    0
# city                          0
# skill_abr                     0
# benefits                      0
# industry                      0
# yearly_salary                 0
# dtype: int64

# %%
jobs.head()
# Out:
#                       title formatted_work_type    application_type  \
# 0  Licensed Insurance Agent           Full-time  ComplexOnsiteApply
# 1             Sales Manager           Full-time  ComplexOnsiteApply
# 2          Business Manager           Full-time  ComplexOnsiteApply
# 3          Office Associate           Full-time  ComplexOnsiteApply
# 4         Education Manager           Full-time        OffsiteApply
#
#   formatted_experience_level           city skill_abr benefits  \
# 0                  Executive          Chico      SALE    Basic
# 1           Mid-Senior level  Santa Clarita      SALE    Basic
# 2                 Internship         Forney      MNFC  Premium
# 3                  Executive         Albany       ADM  Premium
# 4                  Executive  United States       EDU  Premium
#
#                            industry  yearly_salary
# 0                         Insurance   48880.000000
# 1  Transportation/Trucking/Railroad  124065.217391
# ...

# %%
jobs.nunique()
# Out:
# title                         4503
# formatted_work_type              7
# application_type                 3
# formatted_experience_level       6
# city                          1738
# skill_abr                       35
# benefits                         3
# industry                       130
# yearly_salary                 1915
# dtype: int64

# %%
jobs.dtypes
# Out:
# title                          object
# formatted_work_type            object
# application_type               object
# formatted_experience_level     object
# city                           object
# skill_abr                      object
# benefits                       object
# industry                       object
# yearly_salary                 float64
# dtype: object

# %%
# Convert to correct data types
categorical = ['formatted_work_type',	'application_type',	'formatted_experience_level',	'skill_abr',	'benefits',	'industry']

for i in categorical:
  jobs[i] = jobs[i].astype('category')

jobs['yearly_salary'] = jobs['yearly_salary'].astype('int64')

# %%
jobs.dtypes
# Out:
# title                           object
# formatted_work_type           category
# application_type              category
# formatted_experience_level    category
# city                            object
# skill_abr                     category
# benefits                      category
# industry                      category
# yearly_salary                    int64
# dtype: object

# %%
# Check for duplicates
duplicate_rows = jobs.duplicated()
duplicate_rows.value_counts()
# Out:
# False    7931
# True      186
# dtype: int64

# %%
# drop duplicates
jobs = jobs[~duplicate_rows]
jobs.duplicated().value_counts()
# Out:
# False    7931
# dtype: int64

# %%
jobs.rename(columns={'formatted_work_type': 'work_type',
                   'formatted_experience_level': 'experience',
                  'benefits': 'benefit',
                   'skill_abr': 'skill'}, inplace=True)

jobs.head()
# Out:
#                       title  work_type    application_type        experience  \
# 0  Licensed Insurance Agent  Full-time  ComplexOnsiteApply         Executive
# 1             Sales Manager  Full-time  ComplexOnsiteApply  Mid-Senior level
# 2          Business Manager  Full-time  ComplexOnsiteApply        Internship
# 3          Office Associate  Full-time  ComplexOnsiteApply         Executive
# 4         Education Manager  Full-time        OffsiteApply         Executive
#
#             city skill  benefit                          industry  \
# 0          Chico  SALE    Basic                         Insurance
# 1  Santa Clarita  SALE    Basic  Transportation/Trucking/Railroad
# 2         Forney  MNFC  Premium            Religious Institutions
# 3         Albany   ADM  Premium                            Retail
# 4  United States   EDU  Premium                 Computer Software
#
#    yearly_salary
# 0          48880
# 1         124065
# 2          80080
# 3          39500
# ...

# %%
jobs.to_csv('jobs_2.csv', index=False)

from google.colab import files
files.download('jobs_2.csv')
